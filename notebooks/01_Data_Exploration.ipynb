# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv("../data/structured_it_resume_dataset.csv")

# %% [markdown]
# Check data shape

# %%
df.shape
# Out:
# (2400, 7)

# %% [markdown]
# Check Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_role             2400 non-null   object
#  1   education            2400 non-null   object
#  2   Technical skills     2400 non-null   object
#  3   Soft skills          2400 non-null   object
#  4   Tools & frameworks   2400 non-null   object
#  5   Years of experience  2400 non-null   int64
#  6   resume_paragraph     2400 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 131.4+ KB

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# job_role               0
# education              0
# Technical skills       0
# Soft skills            0
# Tools & frameworks     0
# Years of experience    0
# resume_paragraph       0
# dtype: int64

# %% [markdown]
# Job Role Distribution

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df["job_role"])
plt.title("Job Role Distribution")
plt.show()
