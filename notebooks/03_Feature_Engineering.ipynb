# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix)
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# %% [markdown]
# Process data

# %%
df = pd.read_csv("../data/processed_random_imbalanced.csv")
df.head()
# Out:
#          job_role                        education  \
# 0  Data Scientist          BSc in Computer Science
# 1  Data Scientist          BSc in Computer Science
# 2  Data Scientist    MSc in Information Technology
# 3  Data Scientist          Bachelor of Engineering
# 4  Data Scientist  Diploma in Software Development
#
#                                     Technical skills  \
# 0  data visualization, data analysis, project man...
# 1  linux, git, agile methodology, problem solving...
# 2  python, data visualization, problem solving, a...
# 3  linux, problem solving, wireframing, pandas, n...
# 4  git, statistics, data analysis, numpy, system ...
#
#                              Soft skills                 Tools & frameworks  \
# 0  communication, teamwork, adaptability            team collaboration, git
# 1  communication, teamwork, adaptability                       java, docker
# 2  communication, teamwork, adaptability               system design, linux
# 3  communication, teamwork, adaptability  project management, data analysis
# 4  communication, teamwork, adaptability                         sql, linux
#
#    Years of experience                                   resume_paragraph  \
# 0                   12  MSc in Information Technology graduate with 9 ...
# 1                    2  MSc in Information Technology graduate with 4 ...
# 2                    2  MSc in Information Technology graduate with 2 ...
# 3                    9  MSc in Information Technology graduate with 8 ...
# 4                    3  MSc in Information Technology graduate with 8 ...
#
#                                        combined_text  \
# 0  BSc in Computer Science data visualization, da...
# 1  BSc in Computer Science linux, git, agile meth...
# 2  MSc in Information Technology python, data vis...
# 3  Bachelor of Engineering linux, problem solving...
# 4  Diploma in Software Development git, statistic...
#
#                                           clean_text
# 0  bsc computer science data visualization data a...
# 1  bsc computer science linux git agile methodolo...
# 2  msc information technology python data visuali...
# 3  bachelor engineering linux problem solving wir...
# 4  diploma software development git statistics da...

# %% [markdown]
# Define x and y

# %%
X_text = df["clean_text"]
y = df["job_role"]

# %% [markdown]
# Apply TF-IDF (Term Frequency – Inverse Document Frequency) (convert to machine language)

# %%
tfidf = TfidfVectorizer(
    max_features=8000,
    ngram_range=(1,2),
    sublinear_tf=True
)

X = tfidf.fit_transform(X_text)

# %% [markdown]
# Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, train_size=0.8, random_state=100)

# %% [markdown]
# Check shape

# %%
print("Feature Matrix Shape:", X.shape)
# Out:
# Feature Matrix Shape: (2400, 3111)
