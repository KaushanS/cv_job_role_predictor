# %% [markdown]
# Impoert library

# %%
import pandas as pd
import joblib

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, accuracy_score, f1_score

# %% [markdown]
# Load data

# %%
df = pd.read_csv("../data/processed_random_imbalanced.csv")

# %% [markdown]
# TF-IDF

# %%
X_text = df["clean_text"]
y = df["job_role"]

tfidf = TfidfVectorizer(
    max_features=8000,
    ngram_range=(1,2),
    sublinear_tf=True
)

X = tfidf.fit_transform(X_text)

# %% [markdown]
# Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, train_size=0.8, random_state=100)

# %% [markdown]
# Train SVM Model

# %%
final_model = LinearSVC(
    C=1,
    class_weight="balanced",
    max_iter=2000,
    random_state=100
)

final_model.fit(X_train, y_train)
# Out:
# LinearSVC(C=1, class_weight='balanced', max_iter=2000, random_state=100)

# %% [markdown]
# Predict

# %%
y_pred = final_model.predict(X_test)
y_pred
# Out:
# array(['Game Developer', 'DevOps Engineer', 'Machine Learning Engineer',
#        'UI/UX Designer', 'System Administrator', 'Cloud Engineer',
#        'Network Engineer', 'DevOps Engineer', 'QA Engineer',
#        'System Administrator', 'AI Engineer', 'UI/UX Designer',
#        'Frontend Developer', 'System Administrator',
#        'Mobile App Developer', 'Network Engineer',
#        'Site Reliability Engineer', 'Cloud Engineer',
#        'Machine Learning Engineer', 'Security Engineer',
#        'Penetration Tester', 'Cloud Engineer',
#        'Machine Learning Engineer', 'Mobile App Developer',
#        'Penetration Tester', 'Software Engineer', 'DevOps Engineer',
#        'QA Engineer', 'Cybersecurity Analyst', 'DevOps Engineer',
#        'Full Stack Developer', 'Backend Developer', 'Penetration Tester',
#        'UI/UX Designer', 'UI/UX Designer', 'Data Scientist',
#        'AI Engineer', 'Penetration Tester', 'Data Scientist',
#        'Data Analyst', 'Frontend Developer', 'DevOps Engineer',
#        'Frontend Developer', 'Security Engineer',
#        'Site Reliability Engineer', 'AI Engineer', 'Software Engineer',
#        'Mobile App Developer', 'Penetration Tester',
#        'Cybersecurity Analyst', 'Full Stack Developer', 'Data Scientist',
#        'Full Stack Developer', 'Cybersecurity Analyst', 'DevOps Engineer',
#        'UI/UX Designer', 'Backend Developer', 'QA Engineer',
#        'Frontend Developer', 'QA Engineer', 'DevOps Engineer',
#        'Penetration Tester', 'Security Engineer', 'System Administrator',
#        'UI/UX Designer', 'Security Engineer', 'Cybersecurity Analyst',
#        'QA Engineer', 'Machine Learning Engineer', 'Penetration Tester',
#        'Cloud Engineer', 'Backend Developer', 'Network Engineer',
#        'Data Analyst', 'Cloud Engineer', 'QA Engineer',
#        'Software Engineer', 'Software Engineer', 'Full Stack Developer',
#        'System Administrator', 'Data Analyst', 'Software Engineer',
#        'Full Stack Developer', 'Data Analyst', 'Backend Developer',
#        'Data Analyst', 'Software Engineer', 'Backend Developer',
#        'Cybersecurity Analyst', 'Mobile App Developer',
#        'System Administrator', 'UI/UX Designer', 'Game Developer',
#        'Data Scientist', 'System Administrator',
#        'Machine Learning Engineer', 'Penetration Tester', 'QA Engineer',
#        'QA Engineer', 'Machine Learning Engineer', 'Full Stack Developer',
#        'Backend Developer', 'Frontend Developer', 'Security Engineer',
#        'Network Engineer', 'DevOps Engineer', 'Penetration Tester',
#        'Game Developer', 'Game Developer', 'Network Engineer',
#        'Frontend Developer', 'QA Engineer', 'UI/UX Designer',
#        'Game Developer', 'System Administrator', 'UI/UX Designer',
#        'Cybersecurity Analyst', 'QA Engineer', 'UI/UX Designer',
#        'QA Engineer', 'Security Engineer', 'Machine Learning Engineer',
#        'Data Analyst', 'UI/UX Designer', 'Network Engineer',
#        'Backend Developer', 'Network Engineer', 'Data Scientist',
#        'Game Developer', 'Software Engineer', 'Cybersecurity Analyst',
#        'Software Engineer', 'Security Engineer', 'Penetration Tester',
#        'DevOps Engineer', 'Mobile App Developer', 'Mobile App Developer',
#        'DevOps Engineer', 'Security Engineer', 'Network Engineer',
#        'AI Engineer', 'DevOps Engineer', 'Backend Developer',
#        'Cybersecurity Analyst', 'Data Analyst', 'Penetration Tester',
#        'Security Engineer', 'Cloud Engineer', 'Data Analyst',
#        'Frontend Developer', 'Mobile App Developer', 'Frontend Developer',
#        'Game Developer', 'Backend Developer', 'Machine Learning Engineer',
#        'Software Engineer', 'Data Scientist', 'Cybersecurity Analyst',
#        'Site Reliability Engineer', 'QA Engineer', 'Game Developer',
#        'Network Engineer', 'Full Stack Developer', 'Full Stack Developer',
#        'Network Engineer', 'Software Engineer', 'Full Stack Developer',
#        'Data Scientist', 'Cybersecurity Analyst', 'Data Scientist',
#        'Cybersecurity Analyst', 'Cloud Engineer', 'Frontend Developer',
#        'Network Engineer', 'Frontend Developer', 'Game Developer',
#        'QA Engineer', 'Cloud Engineer', 'Network Engineer', 'QA Engineer',
#        'Site Reliability Engineer', 'Network Engineer', 'Data Scientist',
#        'Backend Developer', 'Software Engineer', 'Cloud Engineer',
#        'System Administrator', 'QA Engineer', 'Network Engineer',
#        'Data Analyst', 'UI/UX Designer', 'Game Developer',
#        'Software Engineer', 'Software Engineer', 'Data Analyst',
#        'DevOps Engineer', 'Software Engineer', 'Game Developer',
#        'Software Engineer', 'Security Engineer',
#        'Site Reliability Engineer', 'Cloud Engineer',
#        'Machine Learning Engineer', 'Site Reliability Engineer',
#        'Site Reliability Engineer', 'Machine Learning Engineer',
#        'AI Engineer', 'Cloud Engineer', 'Cybersecurity Analyst',
#        'Site Reliability Engineer', 'Cybersecurity Analyst',
#        'Security Engineer', 'Machine Learning Engineer',
#        'DevOps Engineer', 'Network Engineer', 'Frontend Developer',
#        'Game Developer', 'Cloud Engineer', 'Backend Developer',
#        'Backend Developer', 'System Administrator',
#        'Site Reliability Engineer', 'AI Engineer', 'Software Engineer',
#        'System Administrator', 'Full Stack Developer', 'Data Scientist',
#        'Game Developer', 'Game Developer', 'AI Engineer',
#        'Penetration Tester', 'System Administrator',
#        'System Administrator', 'Data Analyst', 'Frontend Developer',
#        'Data Scientist', 'DevOps Engineer', 'DevOps Engineer',
#        'DevOps Engineer', 'QA Engineer', 'Data Analyst',
#        'Frontend Developer', 'Machine Learning Engineer',
#        'Mobile App Developer', 'Backend Developer', 'Security Engineer',
#        'AI Engineer', 'Machine Learning Engineer', 'QA Engineer',
#        'Penetration Tester', 'Cybersecurity Analyst', 'Backend Developer',
#        'Network Engineer', 'Cybersecurity Analyst', 'Game Developer',
#        'Security Engineer', 'Data Analyst', 'Mobile App Developer',
#        'Network Engineer', 'Game Developer', 'Machine Learning Engineer',
#        'QA Engineer', 'DevOps Engineer', 'Game Developer',
#        'Backend Developer', 'Penetration Tester', 'Data Scientist',
#        'Penetration Tester', 'Cloud Engineer', 'UI/UX Designer',
#        'Software Engineer', 'UI/UX Designer', 'Cybersecurity Analyst',
#        'Network Engineer', 'Machine Learning Engineer',
#        'System Administrator', 'Penetration Tester',
#        'Cybersecurity Analyst', 'Machine Learning Engineer',
#        'DevOps Engineer', 'UI/UX Designer', 'Data Scientist',
#        'Frontend Developer', 'Data Analyst', 'Security Engineer',
#        'Network Engineer', 'Site Reliability Engineer',
#        'Software Engineer', 'Software Engineer', 'AI Engineer',
#        'System Administrator', 'Frontend Developer',
#        'Site Reliability Engineer', 'DevOps Engineer',
#        'Penetration Tester', 'Backend Developer', 'Full Stack Developer',
#        'Security Engineer', 'Software Engineer', 'Full Stack Developer',
#        'Software Engineer', 'Site Reliability Engineer',
#        'Security Engineer', 'Game Developer', 'Full Stack Developer',
#        'Machine Learning Engineer', 'Penetration Tester',
#        'Frontend Developer', 'Security Engineer', 'UI/UX Designer',
#        'Network Engineer', 'Security Engineer',
#        'Site Reliability Engineer', 'QA Engineer', 'Software Engineer',
#        'System Administrator', 'Backend Developer',
#        'Machine Learning Engineer', 'UI/UX Designer', 'Data Scientist',
#        'UI/UX Designer', 'Network Engineer', 'Cloud Engineer',
#        'DevOps Engineer', 'Cybersecurity Analyst', 'Frontend Developer',
#        'Cloud Engineer', 'Cybersecurity Analyst', 'Frontend Developer',
#        'Cloud Engineer', 'Software Engineer', 'Backend Developer',
#        'Cloud Engineer', 'Cloud Engineer', 'Software Engineer',
#        'Full Stack Developer', 'Frontend Developer', 'AI Engineer',
#        'Cloud Engineer', 'Frontend Developer', 'Backend Developer',
#        'Security Engineer', 'Data Analyst', 'Backend Developer',
#        'Site Reliability Engineer', 'Software Engineer',
#        'Full Stack Developer', 'Network Engineer', 'Network Engineer',
#        'Security Engineer', 'Backend Developer', 'System Administrator',
#        'Cloud Engineer', 'Frontend Developer', 'Software Engineer',
#        'Data Analyst', 'Backend Developer', 'Data Scientist',
#        'Data Scientist', 'Full Stack Developer', 'Data Analyst',
#        'QA Engineer', 'Software Engineer', 'Cybersecurity Analyst',
#        'Software Engineer', 'DevOps Engineer', 'Game Developer',
#        'QA Engineer', 'AI Engineer', 'Cloud Engineer',
#        'System Administrator', 'AI Engineer', 'Cybersecurity Analyst',
#        'QA Engineer', 'UI/UX Designer', 'Security Engineer',
#        'Data Analyst', 'Security Engineer', 'Cybersecurity Analyst',
#        'Backend Developer', 'Full Stack Developer', 'Backend Developer',
#        'Mobile App Developer', 'Game Developer', 'Cloud Engineer',
#        'Site Reliability Engineer', 'Software Engineer',
#        'Cybersecurity Analyst', 'Backend Developer',
#        'Mobile App Developer', 'Penetration Tester',
#        'System Administrator', 'Cloud Engineer', 'DevOps Engineer',
#        'QA Engineer', 'Game Developer', 'Full Stack Developer',
#        'Machine Learning Engineer', 'Frontend Developer',
#        'Cybersecurity Analyst', 'Penetration Tester', 'Data Analyst',
#        'UI/UX Designer', 'Mobile App Developer', 'Data Scientist',
#        'Software Engineer', 'Mobile App Developer', 'Data Scientist',
#        'System Administrator', 'DevOps Engineer',
#        'Machine Learning Engineer', 'Software Engineer', 'Data Scientist',
#        'Security Engineer', 'Cybersecurity Analyst', 'UI/UX Designer',
#        'Software Engineer', 'DevOps Engineer', 'Security Engineer',
#        'Cybersecurity Analyst', 'DevOps Engineer', 'Cloud Engineer',
#        'Software Engineer', 'Machine Learning Engineer',
#        'Frontend Developer', 'Frontend Developer', 'QA Engineer',
#        'Backend Developer', 'DevOps Engineer', 'Mobile App Developer',
#        'Data Scientist', 'Penetration Tester', 'Network Engineer',
#        'Site Reliability Engineer', 'Data Scientist', 'Backend Developer',
#        'Cybersecurity Analyst', 'Machine Learning Engineer',
#        'System Administrator', 'Software Engineer',
#        'Full Stack Developer', 'UI/UX Designer',
#        'Machine Learning Engineer', 'Network Engineer', 'UI/UX Designer',
#        'System Administrator', 'AI Engineer', 'Penetration Tester',
#        'Site Reliability Engineer', 'Cloud Engineer', 'Data Analyst',
#        'Software Engineer', 'Software Engineer', 'Full Stack Developer',
#        'Cloud Engineer', 'Data Analyst', 'Frontend Developer',
#        'Network Engineer', 'Full Stack Developer', 'System Administrator',
#        'QA Engineer', 'Backend Developer', 'Software Engineer',
#        'Penetration Tester', 'Data Scientist', 'AI Engineer',
#        'QA Engineer', 'Penetration Tester', 'Full Stack Developer',
#        'Site Reliability Engineer', 'Security Engineer',
#        'Full Stack Developer', 'Backend Developer', 'Penetration Tester',
#        'Full Stack Developer', 'Cloud Engineer', 'UI/UX Designer',
#        'Backend Developer', 'System Administrator', 'Backend Developer'],
#       dtype=object)

# %% [markdown]
# Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#                            precision    recall  f1-score   support
#
#               AI Engineer       1.00      1.00      1.00        14
#         Backend Developer       1.00      1.00      1.00        31
#            Cloud Engineer       1.00      0.96      0.98        28
#     Cybersecurity Analyst       0.96      1.00      0.98        26
#              Data Analyst       0.90      0.95      0.93        20
#            Data Scientist       1.00      0.96      0.98        23
#           DevOps Engineer       1.00      1.00      1.00        26
#        Frontend Developer       0.96      1.00      0.98        24
#      Full Stack Developer       1.00      1.00      1.00        24
#            Game Developer       1.00      0.95      0.98        22
# Machine Learning Engineer       0.96      1.00      0.98        22
#      Mobile App Developer       0.93      0.87      0.90        15
#          Network Engineer       0.96      0.96      0.96        26
#        Penetration Tester       0.96      1.00      0.98        24
#               QA Engineer       1.00      0.96      0.98        27
#         Security Engineer       1.00      1.00      1.00        25
# Site Reliability Engineer       1.00      0.90      0.95        20
#         Software Engineer       1.00      1.00      1.00        37
#      System Administrator       0.96      1.00      0.98        23
#            UI/UX Designer       0.96      1.00      0.98        23
#
#                  accuracy                           0.98       480
#                 macro avg       0.98      0.98      0.98       480
#              weighted avg       0.98      0.98      0.98       480

# %% [markdown]
# Save model

# %%
joblib.dump(final_model, "../models/best_model.pkl")
joblib.dump(tfidf, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']
